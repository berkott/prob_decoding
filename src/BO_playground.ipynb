# %%
import numpy as np

# %%
data = np.array([(775, 25, 40),
(558, 36, 40),
(465, 2, 40),
(369, 211, 40),
(454, 47, 40),
(605, 172, 40),
(417, 121, 40),
(800, 27, 40),
(495, 22, 40),
(450, 61, 40),
(450, 217, 40),
(555, 20, 40),
(463, 20, 40),
(642, 23, 40),
(630, 42, 40),
(544, 156, 40),
(487, 148, 40),
(928, 45, 40),
(370, 298, 40),
(533, 98, 40),
(416, 235, 40),
(523, 5, 40),
(934, 18, 40),
(567, 68, 40),
(558, 3, 40),
(552, 43, 40),
(397, 294, 40),
(521, 27, 40),
(1043, 6, 40),
(766, 173, 40),
(886, 70, 40),
(514, 90, 40),
(655, 30, 40),
(437, 142, 40),
(860, 14, 40),
(359, 252, 40),
(428, 114, 40),
(421, 87, 40),
(870, 37, 40),
(415, 46, 40),
(651, 41, 40),
(370, 177, 40),
(413, 71, 40),
(721, 15, 40),
(651, 124, 40),
(366, 134, 40),
(387, 6, 40),
(387, 371, 40),
(790, 302, 40),
(709, 39, 40),
(422, 73, 40),
(604, 50, 40),
(384, 3, 40),
(402, 130, 40),
(468, 35, 40),
(547, 84, 40),
(656, 27, 40),
(656, 147, 40),
(668, 37, 40),
(466, 27, 40),
(627, 90, 40),
(628, 81, 40),
(583, 294, 40),
(502, 53, 40),
(575, 259, 40),
(361, 105, 40),
(402, 23, 40),
(564, 112, 40),
(350, 38, 40),
(519, 6, 40),
(574, 87, 40),
(815, 67, 40),
(392, 116, 40),
(615, 43, 40),
(352, 50, 40),
(669, 113, 40),
(483, 237, 40),
(399, 14, 40),
(385, 6, 40),
(558, 2, 40),
(383, 256, 40),
(344, 5, 40),
(508, 167, 40),
(681, 9, 40),
(482, 57, 40),
(367, 8, 40),
(551, 23, 40),
(514, 65, 40),
(461, 58, 40),
(367, 160, 40),
(816, 153, 40),
(561, 317, 40),
(478, 145, 40),
(411, 21, 40),
(568, 89, 40),
(351, 2, 40),
(585, 175, 40),
(584, 15, 40),
(551, 106, 40),
(475, 45, 40),
(840, 196, 40),
(548, 9, 40),
(452, 12, 40),
(411, 9, 40),
(638, 253, 40),
(533, 28, 40),
(700, 22, 40),
(375, 96, 40),
(340, 88, 40),
(388, 55, 40),
(466, 100, 40),
(350, 87, 40)])

print(data.shape)
print(np.min(data, axis=0))
print(np.max(data, axis=0))
print(np.median(data, axis=0))
print(np.mean(data, axis=0))
# Out:
# (112, 3)
# [340   2  40]
# [1043  371   40]
# [516.5  59.5  40. ]
# [538.05357143  89.86607143  40.        ]
